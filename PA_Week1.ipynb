# %%
import numpy as np
import pandas as pd
#1.Readingdata
Assignmnet_Data = pd.read_csv(r"C:\Users\Sravanthi\Desktop\Assignment1.csv")

# %%
#counting number of observations recorded for each season
lst=['spring','summer','fall','winter']
i=1
while(i<=4):
    season = Assignmnet_Data.apply(lambda x: True if x['season']== i else False, axis =1)
    numOfRows = len(season[season == True].index)
    print("Number of observations in " ,lst[i-1],"are", numOfRows)
    i+=1
# Out:
# Number of observations in  spring are 2686
# Number of observations in  summer are 2733
# Number of observations in  fall are 2733
# Number of observations in  winter are 2734

# %%
#coutning Number of days which are holidays
holidays=len(Assignmnet_Data[Assignmnet_Data.holiday == 1])
print("number of days which are holidays are",holidays)
#coutning Number of days which are working days
workingdays=len(Assignmnet_Data.loc[Assignmnet_Data['holiday']== 0])
print("number of days which are working days are",workingdays)
# Out:
# number of days which are holidays are 311
# number of days which are working days are 10575

# %%
#counting number of observations for different weathers
lst=['Clear, Few clouds, Partly cloudy, Partly clouds','Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist','Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds','Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog']
i=1
while(i<=4):
    weather = Assignmnet_Data.apply(lambda x: True if x['weather']== i else False, axis =1)
    numOfRows = len(weather[weather == True].index)
    print("Number of observations when the weather is" ,i,"i.e,",lst[i-1],"are", numOfRows)
    i+=1
# Out:
# Number of observations when the weather is 1 i.e, Clear, Few clouds, Partly cloudy, Partly clouds are 7192
# Number of observations when the weather is 2 i.e, Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist are 2834
# Number of observations when the weather is 3 i.e, Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds are 859
# Number of observations when the weather is 4 i.e, Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog are 1

# %%
#Finding the summary staistics for temperature
print("The maximum temperature in Celsius is",Assignmnet_Data['temp'].max())
print("The minimum temperature in Celsius is",Assignmnet_Data['temp'].min())
print("The mean temperature in Celsius is",Assignmnet_Data['temp'].mean())
print("The standrad deviation of temperature in Celsius is",Assignmnet_Data['temp'].std())
print("The median temperature in Celsius is",Assignmnet_Data['temp'].median())
# Out:
# The maximum temperature in Celsius is 41.0
# The minimum temperature in Celsius is 0.82
# The mean temperature in Celsius is 20.230859819952173
# The standrad deviation of temperature in Celsius is 7.791589843987506
# The median temperature in Celsius is 20.5

# %%
#Finding the summary staistics for Humidity
print("The maximum humidity is",Assignmnet_Data['humidity'].max())
print("The minimum humidity is",Assignmnet_Data['humidity'].min())
print("The mean humidity is",Assignmnet_Data['humidity'].mean())
print("The standrad deviation of humidity is",Assignmnet_Data['humidity'].std())
print("The median humidity is",Assignmnet_Data['humidity'].median())
# Out:
# The maximum humidity in Celsius is 100
# The minimum humidity in Celsius is 0
# The mean humidity in Celsius is 61.88645967297446
# The standrad deviation of humidity in Celsius is 19.245033277394786
# The median humidity in Celsius is 62.0

# %%
#Finding the summary staistics for Windspeed
print("The maximum windspeed is",Assignmnet_Data['windspeed'].max())
print("The minimum windspeed is",Assignmnet_Data['windspeed'].min())
print("The mean windspeed is",Assignmnet_Data['windspeed'].mean())
print("The standrad deviation of windspeed is",Assignmnet_Data['windspeed'].std())
print("The median windspeed is",Assignmnet_Data['windspeed'].median())
# Out:
# The maximum windspeed is 56.9969
# The minimum windspeed is 0.0
# The mean windspeed is 12.799395406945093
# The standrad deviation of windspeed is 8.16453732683849
# The median windspeed is 12.998

# %%
#Finding the summary staistics for Users
print("The maximum no of users are",Assignmnet_Data['users'].max())
print("The minimum no of users is",Assignmnet_Data['users'].min())
print("The mean of no of users is",Assignmnet_Data['users'].mean())
print("The standrad deviation of no of users is",Assignmnet_Data['users'].std())
print("The median of no of users is",Assignmnet_Data['users'].median())
# Out:
# The maximum no of users are 977
# The minimum no of users is 1
# The mean of no of users is 191.57413191254824
# The standrad deviation of no of users is 181.14445383028496
# The median of no of users is 145.0

# %%
#2.average number of users in spring(1) and winter(4)
df =Assignmnet_Data.groupby('season')['users'].aggregate('mean')
print("Average number of users for spring are", int(df[1]))
print("Average number of users for winter are", int(df[4]))
print("difference in average users for two seasons",int(df[4]-df[1]))
# Out:
# Average number of users for spring are 116
# Average number of users for winter are 198
# difference in average users for two seasons 82

# %%
#3.Histogram for the number of users(Right Skewed)
Assignmnet_Data.hist(column='users',bins=25,grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002634B4B1D88>]],
#       dtype=object)

# %%
#4.adding a feature “temp_normalized” which represents the normalized value for the feature “temp”.
Assignmnet_Data["temp_normalized"]=(Assignmnet_Data["temp"]-Assignmnet_Data["temp"].min())/(Assignmnet_Data["temp"].min()-
                                                                                            Assignmnet_Data["temp"].max())
Assignmnet_Data
# Out:
#              datetime  season  holiday  workingday  weather   temp  humidity  \
# 0         1/1/11 0:00       1        0           0        1   9.84        81
# 1         1/1/11 1:00       1        0           0        1   9.02        80
# 2         1/1/11 2:00       1        0           0        1   9.02        80
# 3         1/1/11 3:00       1        0           0        1   9.84        75
# 4         1/1/11 4:00       1        0           0        1   9.84        75
# ...               ...     ...      ...         ...      ...    ...       ...
# 10881  12/19/12 19:00       4        0           1        1  15.58        50
# 10882  12/19/12 20:00       4        0           1        1  14.76        57
# 10883  12/19/12 21:00       4        0           1        1  13.94        61
# 10884  12/19/12 22:00       4        0           1        1  13.94        61
# 10885  12/19/12 23:00       4        0           1        1  13.12        66
#
#        windspeed  users  temp_normalized
# ...

# %%
#5.adding a feature “temp_standradized” which represents the standardized value for the feature “temp”.
Assignmnet_Data["temp_standradized"]=((Assignmnet_Data['temp']-Assignmnet_Data['temp'].mean())/(Assignmnet_Data['temp'].std()))
Assignmnet_Data
# Out:
#              datetime  season  holiday  workingday  weather   temp  humidity  \
# 0         1/1/11 0:00       1        0           0        1   9.84        81
# 1         1/1/11 1:00       1        0           0        1   9.02        80
# 2         1/1/11 2:00       1        0           0        1   9.02        80
# 3         1/1/11 3:00       1        0           0        1   9.84        75
# 4         1/1/11 4:00       1        0           0        1   9.84        75
# ...               ...     ...      ...         ...      ...    ...       ...
# 10881  12/19/12 19:00       4        0           1        1  15.58        50
# 10882  12/19/12 20:00       4        0           1        1  14.76        57
# 10883  12/19/12 21:00       4        0           1        1  13.94        61
# 10884  12/19/12 22:00       4        0           1        1  13.94        61
# 10885  12/19/12 23:00       4        0           1        1  13.12        66
#
# ...

# %%
#6. selecting a random sample of 500 observations
Assignmnet_Data.sample(500)
# Out:
#              datetime  season  holiday  workingday  weather   temp  humidity  \
# 5086     12/6/11 0:00       4        0           1        2  20.50        77
# 9420    9/15/12 21:00       3        0           0        1  22.96        52
# 5822    1/17/12 19:00       1        0           1        1  18.86        63
# 4428   10/16/11 13:00       4        0           0        1  24.60        35
# 3958    9/15/11 23:00       3        0           1        1  18.04        67
# ...               ...     ...      ...         ...      ...    ...       ...
# 2127    5/15/11 13:00       2        0           0        1  25.42        73
# 10736  12/13/12 18:00       4        0           1        1  13.12        42
# 1300     3/19/11 1:00       1        0           0        2  23.78        46
# 10377  11/17/12 19:00       4        0           0        1  13.94        53
# 7324     5/4/12 13:00       2        0           1        2  26.24        73
#
# ...

# %%
#7. Selecting every 7th row of the data set
df2 = Assignmnet_Data[Assignmnet_Data.index % 7 == 0]
df2
# Out:
#              datetime  season  holiday  workingday  weather   temp  humidity  \
# 0         1/1/11 0:00       1        0           0        1   9.84        81
# 7         1/1/11 7:00       1        0           0        1   8.20        86
# 14       1/1/11 14:00       1        0           0        2  18.86        72
# 21       1/1/11 21:00       1        0           0        2  16.40        87
# 28        1/2/11 4:00       1        0           0        2  18.86        94
# ...               ...     ...      ...         ...      ...    ...       ...
# 10857  12/18/12 19:00       4        0           1        1  15.58        46
# 10864   12/19/12 2:00       4        0           1        1  11.48        65
# 10871   12/19/12 9:00       4        0           1        1  11.48        75
# 10878  12/19/12 16:00       4        0           1        1  17.22        50
# 10885  12/19/12 23:00       4        0           1        1  13.12        66
#
#        windspeed  users
# ...

# %%
#8. Creating a training and test set where training set contains a random sample of 67% of the observations 
#  in the original data, and test data contains 33% of the original data
from sklearn.model_selection import train_test_split
train, test = train_test_split(Assignmnet_Data, test_size=0.33)
print(len(train))
print(len(test))
print(train)
print(test)
# Out:
# 7293
# 3593
#             datetime  season  holiday  workingday  weather   temp  humidity  \
# 9734   10/9/12 23:00       4        0           1        2  19.68        77
# 5311   12/15/11 9:00       4        0           1        2  14.76        62
# 7447    5/9/12 16:00       2        0           1        2  27.06        50
# 3877   9/12/11 14:00       3        0           1        1  30.34        51
# 2637   6/17/11 19:00       2        0           1        3  26.24        83
# ...              ...     ...      ...         ...      ...    ...       ...
# 9840   10/14/12 9:00       4        0           0        2  19.68        67
# 10103   11/6/12 8:00       4        0           1        1   9.02        69
# 7794     6/5/12 3:00       2        0           1        3  20.50        82
# 5964    2/4/12 17:00       1        0           0        3  12.30        70
# 207     1/9/11 22:00       1        0           0        1   5.74        46
#
#        windspeed  users
# ...
